# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib

# %%
plt.plot([3,1,4,5,2])
plt.ylabel("grade")
plt.savefig('test',dpi=600)#将其转成png文件

# %%
plt.axis([-1,10,0,6])#x坐标-1到10，y坐标0-6
# Out:
# (-1.0, 10.0, 0.0, 6.0)

# %%
plt.subplot(3,2,4)#plt.subplot(3,2,4)#
# Out:
# <AxesSubplot:>

# %%
a = np.arange(0.0,5.0,0.02)
plt.subplot(2,1,2)
plt.plot(a,np.cos(2*np.pi*a),'r--')

# %% [markdown]
# plt.plot(x,y,format_string,**kwargs) 控制曲线的格式字符串'b','g'蓝色和绿色，第二组或更多

# %%
a = np.arange(10)
plt.plot(a,a*1.5,'b-',a,a*2.5,'g:',a,a*3.5,'r--')
matplotlib.rcParams['font.family']='SimHei'#使用中文，font.family显示字体名字，~.style显示风格，~.size显示大小
plt.ylabel("纵值")
plt.title("函数")
plt.text(2,1,r'$x=1.5y$',fontsize=15)
plt.text(4,10,r'$x=2.5y$',fontsize=15)
plt.grid(True)

# %%
plt.subplot2grid((3,3),(0,0),colspan=3)
plt.subplot2grid((3,3),(1,0),colspan=2)
plt.subplot2grid((3,3),(1,2),colspan=2)
plt.subplot2grid((3,3),(2,0))
# Out:
# <AxesSubplot:>

# %%
import matplotlib.gridspec as gridspec
gs = gridspec.GridSpec(3,3)#3*3网格区域
ax1 = plt.subplot(gs[0,:])
ax2 = plt.subplot(gs[1,:-1])

# %%
import matplotlib.pyplot as plt
labels = 'Frogs','Hogs','Dogs','Logs'
sizes = [15,30,45,10]
explode = (0,0.1,0,0)
plt.pie(sizes,explode=explode,labels=labels,autopct='%1.1f%%',shadow=False,startangle=90)
plt.axis('equal')
# Out:
# (-1.2142507666786346,
#  1.134711077927507,
#  -1.1258468317413044,
#  1.101230806657754)

# %%
np.random.seed(0)
mu,sigma = 100,20 #均值和标准差
a = np.random.normal(mu,sigma,size=100)
plt.hist(a,40)#直方有40个
plt.title('Histogram')
# Out:
# Text(0.5, 1.0, 'Histogram')

# %%
N=20
theta = np.linspace(0.0,2*np.pi,N,endpoint = False)
radii = 10*np.random.rand(N)
width = np.pi / 4 * np.random.rand(N)
ax = plt.subplot(111,projection='polar')
bars = ax.bar(theta,radii,width=width,bottom=0.0)#left,height,width
for r,bar in zip(radii,bars):
    bar.set_facecolor(plt.cm.viridis(r / 10.))
    bar.set_alpha(0.5)

# %%
fig,ax = plt.subplots()
ax.plot(10*np.random.randn(10),10*np.random.randn(10),'o')
ax.set_title('Simple Scatter')
# Out:
# Text(0.5, 1.0, 'Simple Scatter')
# c:\users\h'z'y\appdata\local\programs\python\python37\lib\site-packages\IPython\core\pylabtools.py:132: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
